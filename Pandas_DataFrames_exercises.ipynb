# %% [markdown]
# <a href="https://colab.research.google.com/github/JulioFMDB/cursopython/blob/main/Pandas_DataFrames_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios Pandas DataFrames

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.3.5

# %% [markdown]
# ---
# ## Criando DataFrame

# %% [markdown]
# ### Criar um pandas DataFrame vazio

# %%
vazio1 = pd.DataFrame() # == > Aqui o que o exercicio pediu < ==
vazio1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#vazio = pd.DataFrame ({  aqui eu tava brincando com  manipulaçao
#    'A': [1,2,3,4]
#    ,'B': [10,11,12,13]
#    ,'C': [8,6,5,3] 
#}, columns=['A','B','C']) 
#vazio
# Out:
#    A   B  C
# 0  1  10  8
# 1  2  11  6
# 2  3  12  5
# 3  4  13  3

# %%
vazio.index = [ # Aqui eu brinquei com a primeira que criei, e depois fiz o exercicio
    'Brasil'
    ,'Argentina'
    ,'Bunda'
    ,'Teste'
]
vazio
# Out:
#            A   B  C
# Brasil     1  10  8
# Argentina  2  11  6
# Bunda      3  12  5
# Teste      4  13  3

# %%
vazio.info() # Aqui eu brinquei com a primeira que criei, e depois fiz o exercicio
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Brasil to Teste
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0+ bytes

# %%
vazio.size # Aqui eu brinquei com a primeira que criei, e depois fiz o exercicio
# Out:
# 12

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ### Crie um Pandas DataFrames `marvel_df` com os dados abaixo:

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %% [markdown]
# ### Adicione nome nas colunas em `marvel_df`

# %%
marvel_df = pd.DataFrame({
    'SEX:':['male','male','male','male','male','male','male','male','male','female','female','male','male','male','male','male','female','female','female','male']
    ,'Born in:': [1962,1941,1974,1963,1963,1961,1961,1962,1963,1961,1975,1939,1964,1964,1963,1962,1964,1963,1964,1968]
    }, columns = ['SEX:', 'Born in:'])
marvel_df # Eu não lembrava se tinha alguma maneira de separar os dados de maneira automática, então fui na mão mesmo.
# Out:
#       SEX:  Born in:
# 0     male      1962
# 1     male      1941
# 2     male      1974
# 3     male      1963
# 4     male      1963
# 5     male      1961
# 6     male      1961
# 7     male      1962
# 8     male      1963
# 9   female      1961
# 10  female      1975
# 11    male      1939
# 12    male      1964
# 13    male      1964
# 14    male      1963
# 15    male      1962
# 16  female      1964
# 17  female      1963
# 18  female      1964
# 19    male      1968

# %% [markdown]
# ---
# ### Adicione nomes de índice ao `marvel_df` (use o nome do personagem como índice)

# %%
marvel_df.index = [
    'Spider-Man'
    ,'Captain America'
    ,'Wolverine'
    ,'Iron Man'
    ,'Thor'
    ,'Thing'
    ,'Mister Fantastic'
    ,'Hulk'
    ,'Beast'
    ,'Invisible Woman'
    ,'Storm'
    ,'Namor'
    ,'Hawkeye'
    ,'Daredevil'
    ,'Doctor Strange'
    ,'Hank Pym'
    ,'Scarlet Witch'
    ,'Wasp'
    ,'Black Widow'
    ,'Vision'
]
marvel_df # Mesma coisa aqui, fui na mão digitando um a um dos index...Funcionou
# Out:
#                     SEX:  Born in:
# Spider-Man          male      1962
# Captain America     male      1941
# Wolverine           male      1974
# Iron Man            male      1963
# Thor                male      1963
# Thing               male      1961
# Mister Fantastic    male      1961
# Hulk                male      1962
# Beast               male      1963
# Invisible Woman   female      1961
# Storm             female      1975
# Namor               male      1939
# Hawkeye             male      1964
# Daredevil           male      1964
# Doctor Strange      male      1963
# Hank Pym            male      1962
# Scarlet Witch     female      1964
# Wasp              female      1963
# Black Widow       female      1964
# Vision              male      1968

# %%
marvel_df.columns # Verifiquei as colunas
# Out:
# Index(['SEX:', 'Born in:'], dtype='object')

# %%
marvel_df.index # Verifiquei os indices
# Out:
# Index(['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor',
#        'Thing', 'Mister Fantastic', 'Hulk', 'Beast', 'Invisible Woman',
#        'Storm', 'Namor', 'Hawkeye', 'Daredevil', 'Doctor Strange', 'Hank Pym',
#        'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'],
#       dtype='object')

# %% [markdown]
# ### Exclua a coluna de Nomes dos Personagens pois agora ela é um índice

# %%
marvel_df.drop()

# %% [markdown]
# ---
# ### Exclua as linhas 'Namor' e 'Hank Pym'

# %%
marvel_df.drop(['Namor', 'Hank Pym']) #Optei por excluir somente no exercicio, não deletando in-place. Caso quisesse, eu criaria a mesma variável
                                      # marvel_df = marvel_df.drop(['Namor', 'Hank Pym'])
# Out:
#                     SEX:  Born in:
# Spider-Man          male      1962
# Captain America     male      1941
# Wolverine           male      1974
# Iron Man            male      1963
# Thor                male      1963
# Thing               male      1961
# Mister Fantastic    male      1961
# Hulk                male      1962
# Beast               male      1963
# Invisible Woman   female      1961
# Storm             female      1975
# Hawkeye             male      1964
# Daredevil           male      1964
# Doctor Strange      male      1963
# Scarlet Witch     female      1964
# Wasp              female      1963
# Black Widow       female      1964
# Vision              male      1968

# %% [markdown]
# ---
# ## Seleção, Slicing e indexação de DataFrame

# %%
marvel_df.shape # Visualizei o shape para pensar melhor
# Out:
# (20, 2)

# %% [markdown]
# ### Exiba os primeiros 5 elementos de 3 formas diferentes de _slicing_ em `marvel_df`

# %%
marvel_df[:5] # Sliced from pos[0] to pos[5]
# Out:
#                  SEX:  Born in:
# Spider-Man       male      1962
# Captain America  male      1941
# Wolverine        male      1974
# Iron Man         male      1963
# Thor             male      1963

# %% [markdown]
# ---
#
# ### Exiba os 5 últimos elementos de 3 formas diferentes de _slicing_ em `marvel_df`

# %%
marvel_df[15:] # Since i know there are [20] positions as i shaped it, i sliced from [15] to last position.
# Out:
#                  SEX:  Born in:
# Hank Pym         male      1962
# Scarlet Witch  female      1964
# Wasp           female      1963
# Black Widow    female      1964
# Vision           male      1968

# %% [markdown]
# ---
# ### Mostrar apenas o sexo dos 5 primeiros elementos em `marvel_df`

# %%
marvel_df['SEX:'][:5] # Here i selected the column, than sliced it from pos[0] to [:5]
# Out:
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: SEX:, dtype: object

# %% [markdown]
# ---
#
# ### Mostrar o primeiro_aparecimento de todos os elementos médios (excluindo o primeiro e último elemento) em `marvel_df`

# %%
#nao entendi o q fazer

# %% [markdown]
# ---
#
# ### Mostrar o primeiro e o último elemento em `marvel_df`

# %%
marvel_df.iloc[[0, -1]] # Used iloc to print the positions that the exercise asked
# Out:
#             SEX:  Born in:
# Spider-Man  male      1962
# Vision      male      1968

# %% [markdown]
# ---
# ## Manipulação e Operação de DataFrame

# %% [markdown]
# ### Altere a primeira aparição do `Vision` para o ano de 1964

# %%
marvel_df.iloc[-1] #The exercise asked to change the year of a index. Here i located it with iloc
# Out:
# SEX:        male
# Born in:    1968
# Name: Vision, dtype: object

# %%
marvel_df.loc['Vision'] = ['male','1964'] # Here i selected the index, than typed what i wanted to change
marvel_df                                 # Dont know if theres a simple way to do this by selecting the column.
# Out:
#                     SEX: Born in:
# Spider-Man          male     1962
# Captain America     male     1941
# Wolverine           male     1974
# Iron Man            male     1963
# Thor                male     1963
# Thing               male     1961
# Mister Fantastic    male     1961
# Hulk                male     1962
# Beast               male     1963
# Invisible Woman   female     1961
# Storm             female     1975
# Namor               male     1939
# Hawkeye             male     1964
# Daredevil           male     1964
# Doctor Strange      male     1963
# Hank Pym            male     1962
# Scarlet Witch     female     1964
# Wasp              female     1963
# Black Widow       female     1964
# Vision              male     1964

# %% [markdown]
# ---
# ### Adicione uma nova coluna para `marvel_df` chamada de `Anos_Desde` com a diferença entre o ano atual e o ano de primeira aparição.

# %%
# Use a variável ano_atual conforme abaixo:
from datetime import date

ano_atual = np.int16(date.today().strftime("%Y"))
ano_atual
# Out:
# 2022

# %%
marvel_df['Anos_Desde'] = ano_atual
marvel_df['AGE:'] = marvel_df.apply(lambda x: x['Anos_Desde'] - x['Born in:'], axis = 1) # Searched on google how to do this...
marvel_df # Here, by a misstyping i created 2 new columns, than i had to erase both. But the subtract formula has worked.
# Out:
#                     SEX:  Born in:  Current Year:  AGE:
# Spider-Man          male      1962           2022    60
# Captain America     male      1941           2022    81
# Wolverine           male      1974           2022    48
# Iron Man            male      1963           2022    59
# Thor                male      1963           2022    59
# Thing               male      1961           2022    61
# Mister Fantastic    male      1961           2022    61
# Hulk                male      1962           2022    60
# Beast               male      1963           2022    59
# Invisible Woman   female      1961           2022    61
# Storm             female      1975           2022    47
# Namor               male      1939           2022    83
# Hawkeye             male      1964           2022    58
# Daredevil           male      1964           2022    58
# Doctor Strange      male      1963           2022    59
# Hank Pym            male      1962           2022    60
# Scarlet Witch     female      1964           2022    58
# Wasp              female      1963           2022    59
# Black Widow       female      1964           2022    58
# Vision              male      1968           2022    54

# %%
marvel_df = marvel_df.drop(columns=['Anos_Desde']) # Deleting In-Place the one that i created.

# %%
marvel_df = marvel_df.drop(columns=['Idade:']) # Deleting In-Place the one that i created by an acident

# %%
marvel_df
# Out:
#                     SEX:  Born in:  Current Year:  AGE:
# Spider-Man          male      1962           2022    60
# Captain America     male      1941           2022    81
# Wolverine           male      1974           2022    48
# Iron Man            male      1963           2022    59
# Thor                male      1963           2022    59
# Thing               male      1961           2022    61
# Mister Fantastic    male      1961           2022    61
# Hulk                male      1962           2022    60
# Beast               male      1963           2022    59
# Invisible Woman   female      1961           2022    61
# Storm             female      1975           2022    47
# Namor               male      1939           2022    83
# Hawkeye             male      1964           2022    58
# Daredevil           male      1964           2022    58
# Doctor Strange      male      1963           2022    59
# Hank Pym            male      1962           2022    60
# Scarlet Witch     female      1964           2022    58
# Wasp              female      1963           2022    59
# Black Widow       female      1964           2022    58
# Vision              male      1968           2022    54

# %% [markdown]
# ---
# ## DataFrame de Arrays booleanos (também chanado de masks)

# %% [markdown]
# ### Exiba um série booleana que diga as personagens do sexo feminino de `marvel_df`

# %%
cond01 = marvel_df['SEX:'] == 'female'
marvel_df[cond01]
# Out:
#                    SEX:  Born in:  Current Year:  Idade:
# Invisible Woman  female      1961           2022      61
# Storm            female      1975           2022      47
# Scarlet Witch    female      1964           2022      58
# Wasp             female      1963           2022      59
# Black Widow      female      1964           2022      58

# %% [markdown]
# ---
# ### Dado o Pandas DataFrame `marvel_df`, utilize um mácara para selecionar os personagens masculinos

# %%
mask = marvel_df['SEX:'] == 'male'
marvel_df[mask]
# Out:
#                   SEX:  Born in:  Current Year:  Idade:
# Spider-Man        male      1962           2022      60
# Captain America   male      1941           2022      81
# Wolverine         male      1974           2022      48
# Iron Man          male      1963           2022      59
# Thor              male      1963           2022      59
# Thing             male      1961           2022      61
# Mister Fantastic  male      1961           2022      61
# Hulk              male      1962           2022      60
# Beast             male      1963           2022      59
# Namor             male      1939           2022      83
# Hawkeye           male      1964           2022      58
# Daredevil         male      1964           2022      58
# Doctor Strange    male      1963           2022      59
# Hank Pym          male      1962           2022      60
# Vision            male      1968           2022      54

# %% [markdown]
# ---
# ### Dado o Pandas DataFrame `marvel_df`, selecione todos os personagens que tiveram sua primeira aparição após 1970

# %%
cond02 = marvel_df['Born in:'] > 1970
marvel_df[cond02]
# Out:
#              SEX:  Born in:  Current Year:  Idade:
# Wolverine    male      1974           2022      48
# Storm      female      1975           2022      47

# %% [markdown]
# ---
# ### Dado o Pandas DataFrame marvel_df,  selecione todos os personagens femininos que tiveram sua primeira aparição após 1970

# %%
cond03 = ( marvel_df['SEX:'] == 'female') & (marvel_df['Born in:'] > 1970 )
marvel_df[cond03]
# Out:
#          SEX:  Born in:  Current Year:  Idade:
# Storm  female      1975           2022      47

# %% [markdown]
# ---
# ## Estatísticas resumidas do DataFrame

# %% [markdown]
# ### Mostre as estísticas básicas de `marvel_df`

# %%
marvel_df.describe
# Out:
# <bound method NDFrame.describe of                     SEX:  Born in:  Current Year:  Idade:
# Spider-Man          male      1962           2022      60
# Captain America     male      1941           2022      81
# Wolverine           male      1974           2022      48
# Iron Man            male      1963           2022      59
# Thor                male      1963           2022      59
# Thing               male      1961           2022      61
# Mister Fantastic    male      1961           2022      61
# Hulk                male      1962           2022      60
# Beast               male      1963           2022      59
# Invisible Woman   female      1961           2022      61
# Storm             female      1975           2022      47
# Namor               male      1939           2022      83
# Hawkeye             male      1964           2022      58
# Daredevil           male      1964           2022      58
# Doctor Strange      male      1963           2022      59
# Hank Pym            male      1962           2022      60
# Scarlet Witch     female      1964           2022      58
# Wasp              female      1963           2022      59
# Black Widow       female      1964           2022      58
# Vision              male      1968           2022      54>

# %%
marvel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Spider-Man to Vision
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SEX:           20 non-null     object
#  1   Born in:       20 non-null     int64
#  2   Current Year:  20 non-null     int16
#  3   Idade:         20 non-null     int64
# dtypes: int16(1), int64(2), object(1)
# memory usage: 680.0+ bytes

# %% [markdown]
# ---
# ### Dado o Pandas DataFrame `marvel_df`, mostre a média do ano de aparição dos personagens

# %%
marvel_df['Born in:'].mean()
# Out:
# 1961.85

# %% [markdown]
# ---
# ### Dado o Pandas DataFrame marvel_df, mostre o valor mínimo do primeiro ano de aparição

# %%
marvel_df['Born in:'].min()
# Out:
# 1939

# %% [markdown]
# ---
# ### Dado o Pandas DataFrame `marvel_df`, retorne os personagens com valor igual ao menor ano de aparição

# %%
cond04 = marvel_df['Born in:'] == 1939
marvel_df[cond04]
# Out:
#        SEX:  Born in:  Current Year:  Idade:
# Namor  male      1939           2022      83

# %% [markdown]
# ---
# ## Plotagens básicas de DataFrame

# %% [markdown]
# ### Redefinir nomes de índice do `marvel_df`

# %% [markdown]
# ---
# ### Plote os valores de primeira aparição

# %% [markdown]
# ---
# ### Plote um histograma (plot.hist) com os valores do primeiro ano de aparição
